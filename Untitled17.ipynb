# %% [markdown]
# <a href="https://colab.research.google.com/github/VoinovaEA/prog/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задание task_03_01_01.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241

import math
def sgn(x):
    """Вернуть результат сигнум-функции.

    Параметры:
        - x (float): аргумент x.

    Результат:
        float: значение функции.
    """
    if x>0:
      return 1
    elif x==0:
      return 0
    else:
      return -1

x = int(input("Введите x: "))
y = int(input("Введите y: "))
sgn_x = sgn(x)
sgn_y = sgn(y)

g = sgn_y - math.sqrt(abs(x))
if g==0:
  print("Деление на 0")
else:
  z = (sgn_x + y**2)/g
print("Ответ:", round(z,2))

# --------------
# Пример вывода:
#
# Введите x: -9
# Введите y: 0
# Ответ: 0.33
# Out:
# Введите x: -9
# Введите y: 0
# Ответ: 0.33

# %%
# Задание task_03_01_02.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def avg(data):
    """Вернуть среднее значение 'data'.

    Параметры:
        data (list): Список чисел

    Результат:
        float: Среднее значение
    """
    if not data:
      return 0
    return sum(data) // len(data)


def cleared_data(data):
    """Вернуть список без значений None.

    Параметры:
         data (list): Список с возможными значениями None.


    Результат:
        list: Список, очищенный от значений None.
    """
    return [p for p in data if p is not None]


n = int(input("Кол-во измерений: "))

# Если с клавиатуры вводится прочерк, измерения нет
# (необходимо добавить в список None)
data = []

for i in range(1, n+1):
  s = input(f"Измерение {i}-е: ")
  if s == "-":
    data.append(None)
  else:
    data.append(float(s))
cleaned_data = cleared_data(data)

# Получить очищенный список и среднее значение
if cleaned_data:
    average_value = avg(cleaned_data)
    print(f"Средняя температура: {average_value:.2f}")

# --------------
# Пример вывода:
#
# Кол-во измерений: 3
# Измерение 1-е: 10
# Измерение 2-е: -
# Измерение 3-е: 20
# Средняя температура: 15.00
# Out:
# Кол-во измерений: 3
# Измерение 1-е: 10
# Измерение 2-е: -
# Измерение 3-е: 20
# Средняя температура: 15.00

# %%
# Задание task_03_01_03.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def is_lucky(num):
    """Является ли 'num' номером счастливого билета?

    Параметры:
        num(int): номер билета

    Результат:
        bool: True - да, False - нет.
    """
    count_even = 0
    count_odd = 0
    for f in str(num):
      if int(f)%2==0:
        count_even += 1
      else:
        count_odd += 1
    return count_even == count_odd


def lucky_numbers(a, b):
    """Вернуть список счастливых номеров от 'a' до 'b'.

    Параметры:
        a (int): первый номер.
        b (int): последний номер.

    Результат:
        list: список счастливых билетов
    """
    return [num for num in range(a, b + 1) if is_lucky(num)]


a = int(input("Первый номер билета: "))
b = int(input("Последний номер билета: "))

# Вывод должен быть осуществлен в строку с одним пробелом-разделителем
lucky_nums = lucky_numbers(a, b)
print(" ".join(map(str, lucky_nums)))
# --------------
# Пример вывода:
#
# Первый номер билета: 10
# Последний номер билета: 25
# 10 12 14 16 18 21 23 25
# Out:
# Первый номер билета: 10
# Последний номер билета: 25
# 10 12 14 16 18 21 23 25

# %%
# Задание task_03_01_04.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def is_leap(year):
    """Является ли 'year' високосным годом?

    Параметры:
        year(int): год

    Результат:
        bool: True - да, False - нет.
    """
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
      return True
    return False

def days(month, year):
    """Вернуть количество дней в месяце 'month' года 'year'.

    Параметры:
        month(int): месяц
        year(int): год


    Результат:
        int: количество дней в списке
    """
    if month in (1, 3, 5, 7, 8, 10, 12):
        return 31
    elif month in (4, 6, 9, 11):
        return 30
    elif month == 2:
      return 29 if is_leap(year) else 28


def previous_date(day, month, year):
    """Вернуть день, месяц, год предыдущего дня.

    Параметры:
        day(int): день
        month(int): месяц
        year(int): год

    Результат:
        int: день, месяц, год предыдущего дня
    """
    if day > 1:
        return day - 1, month, year
    else:
        if month == 1:
            return 31, 12, year - 1
        else:
            return days(month - 1, year), month - 1, year

    return day, month, year


def next_date(day, month, year):
    """Вернуть день, месяц, год следующего дня.

    Параметры:
        day(int): день
        month(int): месяц
        year(int): год


    Результат:
        int: день, месяц, год следующего дня.

    """
    if day >= 1:
        return day + 1, month, year
    else:
       if month == 12:
            return 1, 1, year + 1
       else:
            return 1, month + 1, year



day, month, year = map(int, input("День, месяц, год через пробел: ").split())
prev_day, prev_month, prev_year = previous_date(day, month, year)
next_day, next_month, next_year = next_date(day, month, year)

print(f"Предыдущий день: {prev_day:02d}/{prev_month:02d}/{prev_year}")
print(f"Следующий день: {next_day:02d}/{next_month:02d}/{next_year}")



# --------------
# Пример вывода:
#
# День, месяц, год через пробел: 1 3 2000
# Предыдущий день: 29/02/2000
# Следующий день: 02/03/2000
# Out:
# День, месяц, год через пробел: 1 3 2000
# Предыдущий день: 29/02/2000
# Следующий день: 02/03/2000

# %%
# Задание task_03_01_05.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def is_leap(year):
    """Является ли 'year' високосным годом?

    Параметры:
        year(int): год

    Результат:
        bool: True - да, False - нет.
    """
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
      return True
    return False


def days(month, year):
    """Вернуть количество дней в месяце 'month' года 'year'.

    Параметры:
        month(int): месяц
        year(int): год


    Результат:
        int: количество дней в списке
    """
    if month in (1, 3, 5, 7, 8, 10, 12):
        return 31
    elif month in (4, 6, 9, 11):
        return 30
    elif month == 2:
      return 29 if is_leap(year) else 28


def another_date(day, month, year, delta=1):
    """Вернуть день, месяц, год, отличающийся на 'delta' дней.

    Параметры:
         year(int): день
         month(int): месяц
         year(int): год

    Результат:
        int: день, месяц, год, отличающийся на 'delta' дней.
    """

    def previous_date(day, month, year):
        """Вернуть день, месяц, год предыдущего дня.

        Параметры:
            year(int): день
            month(int): месяц
            year(int): год

        Результат:
            int: день, месяц, год предыдущего дня
        """
        day -= 1
        if day < 1:
            month -= 1
            if month < 1:
                month = 12
                year -= 1
            day = days(month, year)
        return day, month, year




    def next_date(day, month, year):
        """Вернуть день, месяц, год следующего дня.

        Параметры:
            year(int): день
            month(int): месяц
            year(int): год

        Результат:
            int: день, месяц, год следующего дня.
        """
        day += 1
        if day > days(month, year):
            day = 1
            month += 1
            if month > 12:
                month = 1
                year += 1
        return day, month, year

    for _ in range(abs(delta)):
        if delta < 0:
            day, month, year = previous_date(day, month, year)
        else:
            day, month, year = next_date(day, month, year)

    return day, month, year


day, month, year = map(int, input("День, месяц, год через пробел: ").split())
delta = int(input("Сдвиг (может быть отрицательным): "))

new_day, new_month, new_year = another_date(day, month, year, delta)

print(f"Новый день: {new_day:02d}/{new_month:02d}/{new_year}")
print("")
day, month, year = map(int, input("День, месяц, год через пробел: ").split())
delta = int(input("Сдвиг (может быть отрицательным): "))

new_day, new_month, new_year = another_date(day, month, year, delta)

new_date_message = f"Новый день: {new_day:02d}/{new_month:02d}/{new_year}"
print(new_date_message)

# Удалите комментарий и допишите код

# --------------
# Пример вывода:
#
# День, месяц, год через пробел: 1 1 2000
# Свдиг (может быть отрицательным): -2
# Новый день: 30/12/1999
#
# День, месяц, год через пробел: 1 1 2000
# Свдиг (может быть отрицательным): 2
# Новый день: 03/01/2000
# Out:
# День, месяц, год через пробел: 1 1 2000
# Сдвиг (может быть отрицательным): -2
# Новый день: 30/12/1999
#
# День, месяц, год через пробел: 1 1 2000
# Сдвиг (может быть отрицательным): 2
# Новый день: 03/01/2000

# %%
# Задание task_03_01_06.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def gcd(first, second):
    """Вернуть НОД целых чисел 'first' и 'second'."""
    while second:
        first, second = second, first % second
    return abs(first)

def lcm(first, second):
    """Вернуть НОК целых чисел 'first' и 'second'."""
    return abs(first * second) // gcd(first, second)


def gcd_nums(nums):
    """Вернуть НОД чисел из списка 'nums'.

    Параметры:
        nums: список чисел

    Результат:
        НОД чисел из списка 'nums'
    """
    result = nums[0]
    for num in nums[1:]:
        result = gcd(result, num)
    return result


def lcm_nums(nums):
    """Вернуть НОК чисел из списка 'nums'.

    Параметры:
        nums: список чисел.

    Результат:
        НОК чисел из списка 'nums'.
    """
    result = nums[0]
    for num in nums[1:]:
        result = lcm(result, num)
    return result


nums = input("Введите числа через пробел: ")
nums12 = list(map(int, nums.split()))

gcd_result = gcd_nums(nums12)
lcm_result = lcm_nums(nums12)

print(f"НОД = {gcd_result}")
print(f"НОК = {lcm_result}")
print(" ")
nums = input("Введите числа через пробел: ")
nums12 = list(map(int, nums.split()))

gcd_result = gcd_nums(nums12)
lcm_result = lcm_nums(nums12)

print(f"НОД = {gcd_result}")
print(f"НОК = {lcm_result}")
# --------------
# Пример вывода:
#
# Введите числа через пробел: 8 10 14
# НОД = 2
# НОК = 280
#
# Введите числа через пробел: 6 8 24 16
# НОД = 2
# НОК = 48
# Out:
# Введите числа через пробел: 8 10 14
# НОД = 2
# НОК = 280
#
# Введите числа через пробел: 6 8 24 16
# НОД = 2
# НОК = 48

# %%
# Задание task_03_01_07.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def has_digits(sentence):
    """Является ли символ в предложении цифрой"""
    for p in sentence:
        if p.isdigit():
          return True
    return False


def sentences_with_digits_count(sentences):
    """Возвращаем количество предложений, содержащих цифры."""
    count = 0
    for sentence in sentences:
        if has_digits(sentence):
            count += 1
    return count


n = int(input("Введите количество предложений: "))
sentences = []

for i in range(1, n+1):
  print(f"Введите предложение №{i}: ")
  pi = input()
  sentences.append(pi)

count = sentences_with_digits_count(sentences)
print(f"Предложений с цифрой = {count}")


# --------------
# Пример вывода:
#
# Введите количество предложений: 3
# Введите предложение №1:
# Просто текст
# Введите предложение №2:
# Текст с цифрой 1 (один)
# Введите предложение №3:
# Тут нет цифры
# Предложений с цифрой = 1
# Out:
# Введите количество предложений: 3
# Введите предложение №1:
# Просто текст
# Введите предложение №2:
# Текст с цифрой 1 (один)
# Введите предложение №3:
# Тут нет цифры
# Предложений с цифрой = 1

# %%
# Задание task_03_01_08.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def print_with_border(string, char):
    """Выводит строку с рамкой из символов char."""
    p = len(string) + 2
    print(char * p)
    print(f"{char}{string}{char}")
    print(char * p)


s = input("Введите строку: ")
k = input("Введите символ: ")


print_with_border(s, k)

# --------------
# Пример вывода:
#
# Введите строку: Просто текст
# Введите символ: +
# ++++++++++++++
# +Просто текст+
# ++++++++++++++
# Out:
# Введите строку: Просто текст
# Введите символ: +
# ++++++++++++++
# +Просто текст+
# ++++++++++++++

# %%
# Задание task_03_01_09.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



LETTERS_EX = {10: "A", 11: "B", 12: "C", 13: "D", 14: "E", 15: "F"}
DIGITS_EX = {"A": 10, "B": 11, "C": 12, "D": 13, "E": 14, "F": 15}


def to_base(number, base):
    """Преобразовать десятичное число 'number' в с.с. 'base'.

    Параметры:
        number (int): десятичное число;
        base (int): система счисления.

    Результат:
        str: число в с.с. 'base'."""
    if base < 2 or base > 16:
        raise ValueError
    if number == 0:
        return "0"

    result = ""
    is_negative = number < 0
    number = abs(number)

    while number > 0:
        remainder = number % base
        if remainder >= 10:
            result = LETTERS_EX[remainder] + result
        else:
            result = str(remainder) + result
        number //= base

    if is_negative:
        result = "-" + result

    return result

def from_base(number_str, base):
    """Преобразовать число в с.с. 'base' в десятичное число.

    Параметры:
        number_str (str): число в с.с. 'base';
        base (int): система счисления.

    Результат:
        int: число в 10-й с.с."""

    if base < 2 or base > 16:
        raise ValueError("Основание системы счисления должно быть в диапазоне от 2 до 16.")

    number_str = number_str.upper()
    number = 0

    for digit in number_str:
        if digit.isdigit():
            value = int(digit)
        else:
            value = DIGITS_EX[digit]

        if value >= base:
            raise ValueError(f"Цифра {digit} не может быть в системе счисления с основанием {base}.")

        number = number * base + value

    return number




# --------------
# Пример вывода:
#
# Нет

# %%
# Задание task_03_01_10.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def sentence_stats(sentence):
    """Вернуть символьную статистику 'sentence'. Регистр не учитывается.

    """
    sentence = sentence.lower()
    hom = {}
    for char in sentence:
        if char in hom:
            hom[char] += 1
        else:
            hom[char] = 1

    return hom


s = input("Введите предложение: ")


result = sentence_stats(s)
print(result)


# --------------
# Пример вывода:
#
# Введите предложение: мама МЫла РамУ
# {'л': 1, 'р': 1, 'у': 1, 'м': 4, 'а': 4, 'ы': 1, ' ': 2}
# Out:
# Введите предложение: мама МЫла РамУ
# {'м': 4, 'а': 4, ' ': 2, 'ы': 1, 'л': 1, 'р': 1, 'у': 1}

# %%
# Задание task_03_01_11.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def ceasar(text, shift):
    """Вернуть измененную строку 'text' со сдвигом 'shift'.

    Параметры:
        - text (str): строка;
        - shift (int): свдиг.

    Результат:
        str: измененная строка."""
    # Набор кириллических букв
    letters = [chr(i) for i in range(ord('а'), ord('я') + 1)]
    letters += [chr(i) for i in range(ord('А'), ord('Я') + 1)]

    result = []

    for char in text:
        if char in letters:
            index = letters.index(char)
            new_index = (index + shift) % len(letters)
            result.append(letters[new_index])
        else:
            result.append(char)

    return ''.join(result)


text = input("Введите предложение: ")
shift = int(input("Введите сдвиг: "))

encoded = ceasar(text, shift)
decoded = ceasar(encoded, -shift)




print("Зашифрованная строка:", encoded)
print("Расшифрованная строка:", decoded)

# --------------
# Пример вывода:
#
# Введите предложение: ПрограММиРОВание С++
# Введите сдвиг: 4
# Зашифрованная строка: УфтзфдРРмФТЖдсмй Х++
# Расшифрованная строка: ПрограММиРОВание С++
# Out:
# Введите предложение: ПрограММиРОВание С++
# Введите сдвиг: 4
# Зашифрованная строка: УфтзфдРРмФТЖдсмй Х++
# Расшифрованная строка: ПрограММиРОВание С++

# %%
# Задание task_03_01_12.
#
# Выполнил: Войнова Е.А
# Группа: ЦИБ-241



# В данной задаче ввод с клавиатуры не нужен.
#
# Используйте пример данных ниже, при необходимости измените его для
# проверки правильности решения
data = [
    {1: 'м', 2: 'м', 3: 'м', 4: 'ж'},
    {1: 'ж', 2: 'м', 3: 'ж', 4: 'ж'},
    {1: 'ж', 2: 'ж', 3: 'ж', 4: 'ж'},
    {1: 'м', 2: 'м', 3: 'м', 4: 'м'},
    {1: None, 2: None, 3: None, 4: None},
    {1: 'м', 2: None, 3: None, 4: 'ж'},
    {1: None, 2: None, 3: None, 4: None},
    {1: 'м', 2: 'м', 3: None, 4: 'м'},
    {1: 'ж', 2: None, 3: None, 4: 'ж'}
]

def vacant_compartments(data):
    """Вернуть список полностью свободных купе. Нумерация купе идет с 1."""
    return [i + 1 for i, compartment in enumerate(data) if all(value is None for value in compartment.values())]

def vacant_seats(data, compartments_condition=None, seat_condition=None):
    """Вернуть список свободных мест при соблюдении условий
    'compartments_condition' и 'seat_condition'.
    Нумерация купе и мест идет с 1."""
    result = []
    for i, compartment in enumerate(data):
        if compartments_condition is None or compartments_condition(compartment):
            for seat, value in compartment.items():
                if (seat_condition is None or seat_condition(seat, value)) and value is None:
                    result.append((i + 1, seat))
    return result

def is_same_sex_and_vacant(compartment, sex):
    """Вернуть True, если в купе 'compartment' есть свободные места,
    а остальные пассажиры только пола 'sex'."""
    has_passenger = any(value is not None for value in compartment.values())
    all_same_sex = all(value == sex for value in compartment.values() if value is not None)
    has_vacant = any(value is None for value in compartment.values())
    return has_passenger and all_same_sex and has_vacant

# список полностью свободных купе
print(vacant_compartments(data))
# список свободных мест в вагоне
print(vacant_seats(data))
# список свободных нижних мест
print(vacant_seats(data, seat_condition=lambda seat, value: seat % 2 != 0))
# список свободных верхних мест
print(vacant_seats(data, seat_condition=lambda seat, value: seat % 2 == 0))
# список свободных мест в купе с исключительно мужской компанией
print(vacant_seats(data, lambda x: is_same_sex_and_vacant(x, "м")))
# список свободных мест в купе с исключительно женской компанией
print(vacant_seats(data, lambda x: is_same_sex_and_vacant(x, "ж")))






# --------------
# Пример вывода:
#
# [5, 7]
# [(5, 1), (5, 2), (5, 3), (5, 4), (6, 2), (6, 3), (7, 1), (7, 2), (7, 3),
#  (7, 4), (8, 3), (9, 2), (9, 3)]
# [(5, 1), (5, 3), (6, 3), (7, 1), (7, 3), (8, 3), (9, 3)]
# [(5, 2), (5, 4), (6, 2), (7, 2), (7, 4), (9, 2)]
# [(8, 3)]
# [(9, 2), (9, 3)]
# Out:
# [5, 7]
# [(5, 1), (5, 2), (5, 3), (5, 4), (6, 2), (6, 3), (7, 1), (7, 2), (7, 3), (7, 4), (8, 3), (9, 2), (9, 3)]
# [(5, 1), (5, 3), (6, 3), (7, 1), (7, 3), (8, 3), (9, 3)]
# [(5, 2), (5, 4), (6, 2), (7, 2), (7, 4), (9, 2)]
# [(8, 3)]
# [(9, 2), (9, 3)]

# %%
# Задание task_03_01_13.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



# В данной задаче ввод с клавиатуры не нужен.
#
# Используйте значения 'votes', при необходимости измените его для
# проверки правильности решения

votes = [
    2, 3, -1, 2, 5, 1, 1, 4, 1, 1, 1, 3, 1, 3, 5, -1, 5, 2, 5, 5,
    3, 3, 2, 3, 3, 2, 2, 1, 3, 2, 5, 2, 2, 4, 1, 1, 3, 2, 2, 3, 3,
    3, 1, 4, 2, 1, 4, 2, 3, 3, 3, -1, 5, 3, 1, 4, 5, 1, 1, 3, 3,
    3, -1, 5, 3, 3, 2, 5, 1, 1, 5, -1, 1, 2, 2, 3, -1, 4, 2, 5, 4,
    2, -1, 3, 1, 4, 3, 5, 4, 1, 5, 3, 2, 4, 2, 1, 3, 4, 1, 1, 3, 4
]

parties = {
    1: "Партия №1", 2: "Партия №2", 3: "Партия №3",
    4: "Партия №4", 5: "Партия №5", -1: "Испорчено"
}


def parties_votes(parties, votes):
    """Вернуть информацию о голосах 'votes', отданных за партии 'parties'.
    Испорченные бланки также присутствуют в результате.

    Параметры:
        - parties (dict): информация о партиях (номер голоса: название);
        - votes (list): номера голосов.

    Результат:
        dict: название: кол-во отданных голосов."""
    results = {party_name: 0 for party_name in parties.values()}
    for vote in votes:
        if vote in parties:
            results[parties[vote]] += 1
    return results

def print_results(votes_for_p):
    """Вывести результаты голосования в формате:

    1. Партия №2 | 1111 | 58.21%
    2. Партия №4 |  999 | 38.14%

    Параметры:
        - votes_for_p (dict): результат функции parties_votes().
    """
    total_votes = sum(votes_for_p.values())
    sorted_results = sorted(votes_for_p.items(), key=lambda x: x[1], reverse=True)

    for index, (party_name, count) in enumerate(sorted_results, start=1):
        percentage = (count / total_votes * 100) if total_votes > 0 else 0
        print(f"{index}. {party_name} |{count:>3} | {percentage:.2f}%")

print_results(parties_votes(parties, votes))

# --------------
# Пример вывода:
#
# 1. Партия №3 | 27 | 26.47%
# 2. Партия №1 | 22 | 21.57%
# 3. Партия №2 | 20 | 19.61%
# 4. Партия №5 | 14 | 13.73%
# 5. Партия №4 | 12 | 11.76%
# 6. Испорчено |  7 |  6.86%
# Out:
# 1. Партия №3 | 27 | 26.47%
# 2. Партия №1 | 22 | 21.57%
# 3. Партия №2 | 20 | 19.61%
# 4. Партия №5 | 14 | 13.73%
# 5. Партия №4 | 12 | 11.76%
# 6. Испорчено |  7 | 6.86%

# %%
# Задание task_03_01_14.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def split_numbers(*args):
    """Вернуть 2 списка - отрицательных и неотицательных значений.

    Параметры:
    args: неограниченное количество числовых аргументов

    Результат:
        - list: отрицательные значения;
        - list: неотицательные значения."""
    l = []
    for i in args:
      if i<0:
        l.append(i)

    j = []
    for y in args:
      if y>=0:
       j.append(y)
    return l, sorted(j)



print(split_numbers(1, 4, -5, 0, -33))

# --------------
# Пример вывода:
#
# ([-5, -33], [0, 1, 4])
# Out:
# ([-5, -33], [0, 1, 4])

# %%
# Задание task_03_01_15.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def gdp(c, i, g, ex, im):
    """Вернуть значение ВВП.

    Параметры:
        с - Конечное потребление
        i - Валовое накопление капитала
        g - Государственные расходы
        ex - Экспорт
        im - Импорт.

    Результат:
        Y(значение ВВП).
    """
    return c + i + g + ex - im
c = int(input("Конечное потребление: "))
i = int(input("Валовое накопление капитала: "))
g = int(input("Государственные расходы: "))
ex= int(input("Экспорт: "))
im = int(input("Импорт: "))

values_dict = {'c': c, 'i': i, 'g': g, 'ex': ex, 'im': im}
values_list = [c, i, g, ex, im]

x = gdp(*values_list)
l = gdp(**values_dict)
print(f"ВВП = {x}")
print(f"ВВП = {l}")



# --------------
# Пример вывода:
#
# Конечное потребление: 100
# Валовое накопление капитала: 200
# Государственные расходы: 300
# Экспорт: 400
# Импорт: 500
# ВВП = 500
# ВВП = 500
# Out:
# Конечное потребление: 100
# Валовое накопление капитала: 200
# Государственные расходы: 300
# Экспорт: 400
# Импорт: 500
# ВВП = 500
# ВВП = 500

# %%
# Задание task_03_01_16.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241



def pow1(value, power):
    """Вернуть 'value' в степени 'power'.

    Параметры:
        value - число
        power - степень

    Результат:
       число value в степени power"""
    if power == 0:
      return 1
    elif power < 0:
      return 1 / value ** power
    else:
      return value ** power

def pow2(value, power):
    """Вернуть 'value' в степени 'power'. Рекурсивный алгоритм.

    Параметры:
        value - число
        power - степень.

    Результат:
        число value в степени power."""

    if power == 0:
      return 1
    elif power < 0:
      return 1 / pow2(value, -power)
    else:
      return value * pow2(value, power - 1)


print(pow1(5, 3))
print(pow2(5, 3))

# --------------
# Пример вывода:
#
# 125
# 125
# Out:
# 125
# 125

# %%
# Задание task_03_01_17.
#
# Выполнил: Войнова Екатерина Андреевна
# Группа: ЦИБ-241


def digits_sum(value):
    """Вернуть сумму цифр числа 'value'. Рекурсивная реализация.

    Параметры:
        value - число.

    Результат:
        Сумма цифр в числе value
    """
    if value == 0:
        return 0
    else:
        return value % 10 + digits_sum(value // 10)


def digits_count(value):
    """Вернуть количество цифр числа 'value'. Рекурсивная реализация.

    Параметры:
        value - число

    Результат:
        количество цифр в числе value
    """
    if value == 0:
        return 1
    elif value < 10:
        return 1
    else:
        return 1 + digits_count(value // 10)


print(digits_sum(12345))
print(digits_count(12345))

# --------------
# Пример вывода:
#
# 15
# 5
# Out:
# 15
# 5
